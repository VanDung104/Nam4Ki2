# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
test_data1 = tf.keras.preprocessing.image_dataset_from_directory('Dataset/Test/',
                                                                 label_mode = 'binary',
                                                                 batch_size = 32,
                                                                 image_size= (256, 256),
                                                                shuffle = False)
# Out:
# Found 10905 files belonging to 2 classes.

# %%
print("Các lớp trong tập test:", test_data1.class_names)
# Out:
# Các lớp trong tập test: ['Fake', 'Real']

# %%
def normalize_image(image, labels):
  image = tf.cast(image, tf.float32) / 255.0
  return image, labels

# %%
import matplotlib.pyplot as plt
import cv2
# Technically not necessary in newest versions of jupyter
# %matplotlib inline

# %%
fake = cv2.imread('../Dataset/Train/')

# %%
import tensorflow as tf

# Đường dẫn đến mô hình
model_path = "deepFakeCNN.keras"

# Load mô hình
model = tf.keras.models.load_model(model_path)

# Hiển thị kiến trúc mô hình
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 252, 252, 8)         │             608 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 126, 126, 8)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 126, 126, 8)         │              32 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
test_data = test_data1.map(normalize_image)

# %%
results = model.evaluate(test_data)
# Out:
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 84s 244ms/step - accuracy: 0.9292 - loss: 0.3151

# %%
print("Loss:", results[0])
print("Accuracy:", results[1])  # Nếu model.compile có 'accuracy
# Out:
# Loss: 0.6617453098297119
# Accuracy: 0.8676753640174866

# %% [markdown]
# # Test

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

# %%
y_true = np.concatenate([y.numpy() for _, y in test_data])

# %%
y_true
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [1.],
#        [1.],
#        [1.]], dtype=float32)

# %%
y_pred_prob = model.predict(test_data)  # Xác suất dự đoán
y_pred = (y_pred_prob >= 0.5).astype(int).flatten()  # Chuyển thành 0 hoặc 1

# In confusion matrix
print("Confusion Matrix:")
print(confusion_matrix(y_true, y_pred))
# Out:
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 87s 254ms/step
# Confusion Matrix:
# [[5187  305]
#  [1138 4275]]
#
# Classification Report:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 10
#       8 # In báo cáo chi tiết Precision, Recall, F1-score
#       9 print("\nClassification Report:")
# ---> 10 print(classification_report(y_true, y_pred, target_names=test_data.class_names))
#
# AttributeError: '_MapDataset' object has no attribute 'class_names'

# %%
# In báo cáo chi tiết Precision, Recall, F1-score
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=test_data1.class_names))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#         Fake       0.82      0.94      0.88      5492
#         Real       0.93      0.79      0.86      5413
#
#     accuracy                           0.87     10905
#    macro avg       0.88      0.87      0.87     10905
# weighted avg       0.88      0.87      0.87     10905

# %%
img_path = 'Dataset/Real_img/jungkook-bts-2-16776008141862121.jpg'


img = image.load_img(img_path, target_size=(256, 256))
img_array = image.img_to_array(img) 
img_array = img_array / 255.0
img_array = np.expand_dims(img_array, axis=0)


predictions = model.predict(img_array)


print("Predicted value:", predictions)

if predictions[0] >= 0.5:
    print("Dự đoán: Lớp 1")
else:
    print("Dự đoán: Lớp 0")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Predicted value: [[1.]]
# Dự đoán: Lớp 1

# %% [markdown]
# # Deploy

# %%
def preprocess_image(image_path):
    img = Image.open(image_path).convert("RGB")
    img = img.resize((256, 256))  # Resize theo kích thước model
    img_array = np.array(img) / 255.0  # Chuẩn hóa về [0,1]
    img_array = np.expand_dims(img_array, axis=0)  # Thêm batch dimension
    return img_array

# %% [markdown]
# # Test 2

# %%
import tensorflow as tf

# Đường dẫn đến mô hình
model_path = "deepfake_efficient.h5"

# Load mô hình
model = tf.keras.models.load_model(model_path)

# Hiển thị kiến trúc mô hình
model.summary()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ efficientnetb0 (Functional)          │ (None, 7, 7, 1280)          │       4,049,571 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 1280)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
model.summary
# Out:
# <bound method Model.summary of <Sequential name=sequential, built=True>>
